# %% [markdown]
# Objective: to predict housing prices in New York City using various regression models
#
# Data: NYC housing data from Kaggle, originally from Zillow API as of January 2021
#
# 1. Imported data
#
# 2. Cleaned dataset to be more readible, to ensure right data types for regression, and to drop outliers
#
# 3. Ran LASSO Regression 100 times to optimize and get model with greatest R^2 value -- resulting R^2 score of around 0.45
#
# 4. Ran Random Forest Regression to get model -- resulting R^2 of around 0.76
#
# 5. Exported Random Forest Regression model for later use, then loaded model to run on test data

# %%
import os
import pandas as pd
import numpy as np
from scipy import stats
import pickle
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
df = pd.read_csv(os.path.join("..", "clean_ny_housing.csv"))
# Out:
# C:\Users\achen\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (101,102,113,114,115,116) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# cleaning the dataset

def makeAdjustments(df):
    
    # changing photo columns to a single count column -- 'photos/'
    photo_count = []
    for i in range(len(df)):
        temp = 0
        for j in range(81): #81 photo columns in df
            col = 'photos/' + str(j)
            if pd.notna(df[col][i]):
                temp += 1
        photo_count.append(temp)
    df['photo_count'] = photo_count
    df = df.drop(df.loc[:,'photos/0':'photos/80'], axis = 1)
    
    # changing appliance columns to a single count column -- 'resoFactsStats/appliances/'
    appliance_count = []
    for i in range(len(df)):
        temp = 0
        for j in range(11): #11 photo columns in df
            col = 'resoFactsStats/appliances/' + str(j)
            if pd.notna(df[col][i]):
                temp += 1
        appliance_count.append(temp)
    df['appliance_count'] = photo_count
    df = df.drop(df.loc[:, 'resoFactsStats/appliances/0':'resoFactsStats/appliances/10'].columns, axis = 1)
    
    # changing community features columns to a single count column -- 'resoFactsStats/communityFeatures/0'
    commfeature_count = []
    for i in range(len(df)):
        temp = 0
        for j in range(6): #6 photo columns in df
            col = 'resoFactsStats/communityFeatures/' + str(j)
            if pd.notna(df[col][i]):
                temp += 1
        commfeature_count.append(temp)
    df['commfeature_count'] = photo_count
    df = df.drop(df.loc[:, 'resoFactsStats/communityFeatures/0':'resoFactsStats/communityFeatures/5'].columns, axis = 1)
    
    # remove not heating from 'resoFactsStats/atAGlanceFacts/2/factLabel' 
    # remove not cooling from 'resoFactsStats/atAGlanceFacts/3/factLabel'
    # remove not parking from 'resoFactsStats/atAGlanceFacts/4/factValue'
    # remove not days on zillow from 'resoFactsStats/atAGlanceFacts/6/factLabel'
    todrop = []
    for i in range(len(df)):
        if(
            df['resoFactsStats/atAGlanceFacts/2/factLabel'][i] != 'Heating' or 
            df['resoFactsStats/atAGlanceFacts/3/factLabel'][i] != 'Cooling' or
            df['resoFactsStats/atAGlanceFacts/4/factLabel'][i] != 'Parking' or
            df['homeStatus'][i] != 'FOR_SALE'
        ):
                todrop.append(i)
    df = df.drop(todrop, axis=0)
    df = df.drop(['resoFactsStats/atAGlanceFacts/2/factLabel', 'resoFactsStats/atAGlanceFacts/3/factLabel', 'resoFactsStats/atAGlanceFacts/4/factLabel', 
                  'homeStatus'], axis=1)
    
    # renaming columns above and reassigning as booleans
    df = df.rename(columns={
        'resoFactsStats/atAGlanceFacts/2/factValue': 'Heating',
        'resoFactsStats/atAGlanceFacts/3/factValue': 'Cooling',
        'resoFactsStats/atAGlanceFacts/4/factValue': 'Parking',
    })
    
    df['Heating'] = [pd.notna(val) for val in df['Heating']]
    df['Cooling'] = [pd.notna(val) for val in df['Cooling']]
    df['Parking'] = [pd.notna(val) for val in df['Parking']]
    
    # assigning dummy to categorial variables
    df['address/city'].str.lower()
    
    cat_variables = df[['address/city', 'resoFactsStats/atAGlanceFacts/0/factValue']]
    cat_dummies = pd.get_dummies(cat_variables)
    df.drop(['address/city', 'resoFactsStats/atAGlanceFacts/0/factValue'], axis=1, inplace=True)
    df = pd.concat([df, cat_dummies], axis=1)
    
    df = df.drop(['address/zipcode', 'latitude', 'longitude', 'Heating', 'Cooling', 'Parking', 'dateposted'], axis = 1)
    # why is that comma at the end of the drop list raising R^2???
    
    # typecasting any objects to numeric
    df['resoFactsStats/atAGlanceFacts/1/factValue'] = pd.to_numeric(df['resoFactsStats/atAGlanceFacts/1/factValue'])
    
    # drop rows with na
    df = df.dropna()
    
    # columns = ['bedrooms', 'bathrooms', 'livingArea', 'price', 'propertyTaxRate', 'resoFactsStats/atAGlanceFacts/1/factValue', 'photo_count', 'appliance_count', 'commfeature_count']
    # for i in columns:
    #     df2[(np.abs(stats.zscore(df2[i])) < 2)]
    df[(np.abs(stats.zscore(df['bedrooms'])) < 2)]
    df[(np.abs(stats.zscore(df['bathrooms'])) < 2)]
    df[(np.abs(stats.zscore(df['livingArea'])) < 2)]
    df[(np.abs(stats.zscore(df['price'])) < 2)]
    df[(np.abs(stats.zscore(df['propertyTaxRate'])) < 2)]
    df[(np.abs(stats.zscore(df['resoFactsStats/atAGlanceFacts/1/factValue'])) < 2)]
    df[(np.abs(stats.zscore(df['photo_count'])) < 2)]
    df[(np.abs(stats.zscore(df['appliance_count'])) < 2)]
    df[(np.abs(stats.zscore(df['commfeature_count'])) < 2)]

    return df

# %% [markdown]
# LASSO Regression

# %%
def runRegression(df):
    # creating train and test data set
    train , test = train_test_split(df2, test_size = 0.3)

    x_train = train.drop('price', axis=1)
    y_train = train['price']

    x_test = test.drop('price', axis = 1)
    y_test = test['price']

    # define model
    model = Lasso(alpha=1.0)
    # fit model
    model.fit(x_train, y_train)
    
    # get r^2
    y_pred = model.predict(x_test)
    score = r2_score(y_test, y_pred)
    
    return model, score

# %%
maxscore = 0
model = ''
df2 = makeAdjustments(df)
for i in range(100):
    result = runRegression(df)
    if result[1] > maxscore:
        maxscore = result[1]
        model = result[0]

print('score: ', maxscore)
# Out:
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.0374473701974456e+16, tolerance: 6505732490905.421
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.5922148145296852e+16, tolerance: 5319779408891.282
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.4831457337056466e+16, tolerance: 4867627904478.34
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6968674604806896e+16, tolerance: 5710414269542.57
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9511637857279508e+16, tolerance: 5935657989652.162
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6586225802350118e+16, tolerance: 5694047946119.597
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3240540850294706e+16, tolerance: 4933097746234.118
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9398347769450636e+16, tolerance: 6175309791449.901
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.5891380389645716e+16, tolerance: 5166702577695.946
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.086990999631633e+16, tolerance: 6482369358787.203
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7516708429532848e+16, tolerance: 5790741003730.042
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.910811273083354e+16, tolerance: 6024777775534.362
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.930663009063516e+16, tolerance: 6388475224188.666
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.0249078184762836e+16, tolerance: 6433977155986.499
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8465407944773796e+16, tolerance: 5991186373116.266
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7752508155864544e+16, tolerance: 5661713086013.261
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7780495108543984e+16, tolerance: 5692727006303.045
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.088535562224683e+16, tolerance: 6163300238687.042
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6516546989260626e+16, tolerance: 5353060714724.614
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8146755795815304e+16, tolerance: 6179610592228.464
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.004697982756147e+16, tolerance: 6415498223880.322
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9910084444847228e+16, tolerance: 6380260662384.942
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.5382980172311856e+16, tolerance: 5277501160419.305
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.824606862725241e+16, tolerance: 6006343687400.668
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6452097011481472e+16, tolerance: 5548666205574.105
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9832994740804012e+16, tolerance: 6317147589456.351
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.60461730551127e+16, tolerance: 5454155168270.739
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.460874233586385e+16, tolerance: 5220114126228.538
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.5225158680423986e+16, tolerance: 5164509343108.845
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.4371077726778608e+16, tolerance: 5062637986673.751
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.856944582181573e+16, tolerance: 6021058045490.288
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.962981504547005e+16, tolerance: 6554988808901.922
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8279093657155784e+16, tolerance: 5989295027200.579
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9612407523587244e+16, tolerance: 6033116892873.659
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7997890847279544e+16, tolerance: 5992255103254.079
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.844484289495904e+16, tolerance: 6219468855830.661
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.620963903293463e+16, tolerance: 5361332423054.097
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6150832716351498e+16, tolerance: 5412365958045.636
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6891870080292432e+16, tolerance: 5582926200005.997
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8992747200430204e+16, tolerance: 6314041723924.697
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.255947227303162e+16, tolerance: 6782981750879.602
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7543169356229954e+16, tolerance: 5719134061103.155
#   model = cd_fast.enet_coordinate_descent(
# score:  0.45470483931104055
# C:\Users\achen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.113617591110473e+16, tolerance: 6528018362433.1455
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# Random Forest Linear Regression

# %%
df2 = makeAdjustments(df)

# creating train and test data set
train , test = train_test_split(df2, test_size = 0.3, random_state=42)

x_train = train.drop('price', axis=1)
y_train = train['price']

x_test = test.drop('price', axis = 1)
y_test = test['price']
    
# fit regressor for random forest linear regression
model = RandomForestRegressor(n_estimators = 100, random_state = 0)
model.fit(x_train, y_train) 
y_pred = model.predict(x_test)

# # scoring using rmse
# mse = mean_squared_error(y_test, y_pred)
# rmse = np.sqrt(mse)
# print('RMSE:', rmse)

# # scoring using mae
# mae = mean_absolute_error(y_test, y_pred)
# print('MAE: ', mae)

# save the model to disk
pickle.dump(model, open('nyc_housing_regression.sav', 'wb'))

# %%
loaded_model = pickle.load(open('nyc_housing_regression.sav', 'rb'))
print('score: ', r2_score(y_test, y_pred))
# Out:
# score:  0.7580404997577922
